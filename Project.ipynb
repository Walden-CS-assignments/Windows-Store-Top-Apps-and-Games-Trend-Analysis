# %%
import pandas as pd
import numpy as np

# %%
#不知道为什么用不了
#d_parser = lambda x: pd.datetime.strptime(x, '%d-%m-%Y')
#df = pd.read_csv('windows_store.csv', parse_dates=['Date of Release'], date_parser=d_parser)

# %%
df = pd.read_csv('windows_store.csv')

# %%
df
# Out:
#                                 Name     Price  \
# 0                   WhatsApp Desktop      Free
# 1                   Telegram Desktop      Free
# 2     Amazon Prime Video for Windows      Free
# 3                          Instagram      Free
# 4                      Spotify Music      Free
# ...                              ...       ...
# 3955           Vegas Slots Machine *  ₹ 109.00
# 3956              Crossword Puzzle +  ₹ 109.00
# 3957                     Rescue Team  ₹ 219.00
# 3958                  Doodle Kingdom   ₹ 29.00
# 3959                    Doodle Devil   ₹ 29.00
#
#                                             Description  \
# 0     With WhatsApp on the desktop, you can seamless...
# 1     Pure instant messaging — simple, fast, secure,...
# 2     Watch movies and TV shows recommended for you,...
# 3     Bringing you closer to the people and things y...
# 4     Love music? Play your favorite songs and album...
# ...

# %%
df['Date of Release'] = pd.to_datetime(df['Date of Release'], format = '%d-%m-%Y')

# %%
df
# Out:
#                                 Name     Price  \
# 0                   WhatsApp Desktop      Free
# 1                   Telegram Desktop      Free
# 2     Amazon Prime Video for Windows      Free
# 3                          Instagram      Free
# 4                      Spotify Music      Free
# ...                              ...       ...
# 3955           Vegas Slots Machine *  ₹ 109.00
# 3956              Crossword Puzzle +  ₹ 109.00
# 3957                     Rescue Team  ₹ 219.00
# 3958                  Doodle Kingdom   ₹ 29.00
# 3959                    Doodle Devil   ₹ 29.00
#
#                                             Description  \
# 0     With WhatsApp on the desktop, you can seamless...
# 1     Pure instant messaging — simple, fast, secure,...
# 2     Watch movies and TV shows recommended for you,...
# 3     Bringing you closer to the people and things y...
# 4     Love music? Play your favorite songs and album...
# ...

# %%
df.dtypes
# Out:
# Name                       object
# Price                      object
# Description                object
# Publisher                  object
# Date of Release    datetime64[ns]
# Category                   object
# Size                       object
# Age Rating                 object
# Languages                  object
# dtype: object

# %%
df['Date of Release'].dt.day_name()
# Out:
# 0       Wednesday
# 1          Monday
# 2          Monday
# 3          Friday
# 4          Friday
#           ...
# 3955      Tuesday
# 3956      Tuesday
# 3957    Wednesday
# 3958       Monday
# 3959       Monday
# Name: Date of Release, Length: 3960, dtype: object

# %%
df.set_index('Date of Release', inplace=True)

# %%
df
# Out:
#                                            Name     Price  \
# Date of Release
# 2017-02-01                     WhatsApp Desktop      Free
# 2017-04-03                     Telegram Desktop      Free
# 2020-02-24       Amazon Prime Video for Windows      Free
# 2016-02-26                            Instagram      Free
# 2017-05-26                        Spotify Music      Free
# ...                                         ...       ...
# 2018-01-30                Vegas Slots Machine *  ₹ 109.00
# 2018-01-30                   Crossword Puzzle +  ₹ 109.00
# 2013-05-29                          Rescue Team  ₹ 219.00
# 2013-11-25                       Doodle Kingdom   ₹ 29.00
# 2012-09-24                         Doodle Devil   ₹ 29.00
#
#                                                        Description  \
# Date of Release
# 2017-02-01       With WhatsApp on the desktop, you can seamless...
# 2017-04-03       Pure instant messaging — simple, fast, secure,...
# ...

# %%
df.dtypes
# Out:
# Name           object
# Price          object
# Description    object
# Publisher      object
# Category       object
# Size           object
# Age Rating     object
# Languages      object
# dtype: object

# %%
#不知道为什么，这两个都跑不了。。。。
df['2020']
df['2020-06-10' : '2020-09-10']
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-662f57486ced> in <module>
# ----> 1 df['2020-06' : '2020-09']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3005             # either we have a slice or we have a string that can be converted
#    3006             #  to a slice for partial-string date indexing
# -> 3007             return self._slice(indexer, axis=0)
#    3008
#    3009         # Do we have a (boolean) DataFrame?
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _slice(self, slobj, axis)
#    3807         Slicing with this method is *always* positional.
#    3808         """
# -> 3809         assert isinstance(slobj, slice), type(slobj)
#    3810         axis = self._get_block_manager_axis(axis)
# ...

# %%
df.loc['2019']
# Out:
#                                                               Name  \
# Date of Release
# 2019-11-19                                              Python 3.9
# 2019-08-08                                         Adobe Lightroom
# 2019-02-01                                                  iCloud
# 2019-06-09                                                    Xbox
# 2019-04-23       WPS Office Suite - PDF, Word, Spreadsheet, Sli...
# ...                                                            ...
# 2019-01-24                                     Submarine Attack 3D
# 2019-03-29                               Operencia: The Stolen Sun
# 2019-04-26                                      Fly.Die.Repeat. 76
# 2019-01-01                 Labyrinths of the World: Forbidden Muse
# 2019-08-14                            Dracula 5 : The Blood Legacy
#
#                                    Price  \
# Date of Release
# 2019-11-19                          Free
# ...

# %%
df.loc['2021-01-01' : '2021-02-01']
# Out:
# <ipython-input-33-0498393f6f47>:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df.loc['2021-01-01' : '2021-02-01']
#                                                               Name  \
# Date of Release
# 2021-01-13                                     Dell Mobile Connect
# 2021-01-11                                           CamScanner PC
# 2021-01-08       Real PDF Creator for Office Free - Word to PDF...
# 2021-01-08                     Journal, a Microsoft Garage project
# 2021-01-21                                        X Live Wallpaper
# ...                                                            ...
# 2021-01-29                                            Another Dawn
# 2021-01-25                        Hidden Words Puzzles : PC & XBOX
# 2021-01-15                          Crossword Puzzles+ : PC & XBOX
# ...

# %%
df.loc[0, 'Date of Release'].day_name

# %%
df['Date'] = pd.to_datetime(df['Date of Release'], format = '%d-%m-%Y')

# %%
df['Date of Release']

# %%
df.loc[0, 'Date'].day_name()

# %%
df['Date'].dt.day_name()

# %%
df['DateofWeek'] = df['Date'].dt.day_name()

# %%
df

# %%
df['Date'].max()

# %%
df['Date'].min()

# %%
df['Date'].max()-df['Date'].min()

# %%
filt = (df['Date'] >= pd.to_datetime('2020-01-01')) & (df['Date'] < pd.to_datetime('2020-08-01'))
df.loc[filt]

# %%
filt1 = df['Size'].str.contains('KB', na=False)

# %%
def update_size(size):
    if size.str.contains('KB'):
        
    if size.str.contains('GB'):

# %%
df.loc[filt1, 'Size'] = '1MB

# %%
len(df[filt1])

# %%
将普通apps和游戏apps分成两组，去算top里每种种类的占比

# %%
Cat_Social = df['Category'] == 'Social' 
Cat_Entertainment = df['Category'] == 'Entertainment'
Cat_Music = df['Category'] == 'Music'
Cat_Photo = df['Category'] == 'Photo & video'
Cat_Productivity = df['Category'] == 'Productivity'
Cat_Developer = df['Category'].str.contains('Developer')
Cat_Utilities = df['Category'] == 'Utilities & tools'
Cat_Multimedia = df['Category'].str.contains('Multimedia')
Cat_Shopping = df['Category'] == 'Shopping'
Cat_BusinessD = df['Category'].str.contains('Business','Data')
Cat_BusinessC = df['Category'].str.contains('Business','Collaboration')
Cat_Personalization = df['Category'].str.contains('Personalization')

# %%
print(len(df[Cat_Social]))
print(len(df[Cat_Entertainment]))

# %%
df['Size'].str.split(' ', expand=True)

# %%
df[['SizeNum','SizeUnit']] = df['Size'].str.split(' ', expand=True)
df

# %%
df['Category'].value_counts()

# %%
df['Price'].value_counts()
